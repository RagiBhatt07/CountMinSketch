# %%
from math import ceil, exp, log
import random
import numpy as np
import time
from collections import Counter

# %% [markdown]
# #As mentioned in the paper, Theorem 1 (Theorem 1 from [5]). If w = d
# w = d^(eε)
#
# d = dln(1/δ)/e
# , the estimate aˆi has the following guarantees: ai ≤ aˆi; and,
# with probability at least 1 − δ,
# aˆi ≤ ai + εkak1.

# %%
#define the count min sketch class
#The count min sketch class is used to estimate the frequency of items in a stream of data

class CountMinSketch:
    def __init__(self, epsilon, delta):
        self.epsilon = epsilon
        self.delta = delta
        self.width = ceil(exp(1) / epsilon)
        self.depth = ceil(log(1 / delta))
        self.table = np.zeros((self.depth, self.width), dtype=np.int32)
        self.hashA = [random.randint(1, 1000000007) for i in range(self.depth)]
        self.hashB = [random.randint(1, 1000000007) for i in range(self.depth)]

    def hash(self, word, a, b):
        return (a * hash(word) + b) % self.width

    def update(self, word):
        for i in range(self.depth):
            self.table[i][self.hash(word, self.hashA[i],self.hashB[i])] += 1

    def query(self, word):
        return min(self.table[i][self.hash(word, self.hashA[i],self.hashB[i])] for i in range(self.depth))

    def __str__(self):
        return str(self.table)

# %%
#implement the count min sketch algorithm

if __name__ == '__main__':
    epsilon = 0.001
    delta = 0.01
    
    #initialize the count min sketch
    cms = CountMinSketch(epsilon, delta)

    #read the file and create a list of words
    with open('lai-eliduc.txt', 'r') as f:
        words = f.read().split()


    #update the count min sketch
    for w in words:
        cms.update(w)

    actual_count = Counter(words)
    for word in actual_count:
        print(word)
        print("The actual count", actual_count[word])
        print("The approximate count by cms:",cms.query(word))
        print("The error is:", abs(actual_count[word] - cms.query(word)))
# Out:
# De
# The actual count 53
# The approximate count by cms: 54
# The error is: 1
# un
# The actual count 27
# The approximate count by cms: 27
# The error is: 0
# mut
# The actual count 33
# The approximate count by cms: 36
# The error is: 3
# ancïen
# The actual count 1
# The approximate count by cms: 1
# The error is: 0
# lai
# The actual count 3
# The approximate count by cms: 3
# The error is: 0
# bretun
# The actual count 1
# The approximate count by cms: 1
# The error is: 0
# Le
# The actual count 12
# The approximate count by cms: 12
# The error is: 0
# cunte
# The actual count 2
# The approximate count by cms: 2
# The error is: 0
# e
# The actual count 101
# The approximate count by cms: 101
# The error is: 0
# tute
# The actual count 8
# The approximate count by cms: 10
# The error is: 2
# la
# The actual count 136
# The approximate count by cms: 136
# The error is: 0
# reisun
# The actual count 2
# The approximate count by cms: 5
# The error is: 3
# Vus
# The actual count 4
# The approximate count by cms: 4
# The error is: 0
# dirai,
# The actual count 1
# The approximate count by cms: 1
# The error is: 0
# si
# The actual count 48
# The approximate count by cms: 48
# The error is: 0
# cum
# The actual count 12
# The approximate count by cms: 12
# The error is: 0
# jeo
# The actual count 19
# The approximate count by cms: 21
# The error is: 2
# entent
# The actual count 1
# The approximate count by cms: 4
# The error is: 3
# La
# The actual count 35
# The approximate count by cms: 36
# The error is: 1
# verité,
# The actual count 2
# The approximate count by cms: 2
# The error is: 0
# mun
# The actual count 13
# The approximate count by cms: 13
# The error is: 0
# escïent.
# The actual count 1
# The approximate count by cms: 1
# The error is: 0
# En
# The actual count 15
# The approximate count by cms: 15
# The error is: 0
# Britaine
# The actual count 1
# The approximate count by cms: 1
# The error is: 0
# ot
# The actual count 30
# The approximate count by cms: 30
# The error is: 0
# chevalier
# The actual count 6
# The approximate count by cms: 7
# The error is: 1
# Pruz
# The actual count 1
# The approximate count by cms: 1
# The error is: 0
# curteis,
# The actual count 4
# The approximate count by cms: 4
# The error is: 0
# hardi
# The actual count 3
# The approximate count by cms: 4
# The error is: 1
# fier
# The actual count 1
# The approximate count by cms: 1
# The error is: 0
# ;
# The actual count 19
# The approximate count by cms: 19
# The error is: 0
# Elidus
# The actual count 11
# The approximate count by cms: 19
# The error is: 8
# nun,
# The actual count 2
# The approximate count by cms: 2
# The error is: 0
# ceo
# The actual count 33
# The approximate count by cms: 34
# The error is: 1
# m'est
# The actual count 3
# The approximate count by cms: 19
# The error is: 16
# vis,
# The actual count 2
# The approximate count by cms: 2
# The error is: 0
# N'ot
# The actual count 2
# The approximate count by cms: 8
# The error is: 6
# vaillant
# The actual count 1
# The approximate count by cms: 1
# The error is: 0
# hume
# The actual count 2
# The approximate count by cms: 3
# The error is: 1
# al
# The actual count 27
# The approximate count by cms: 27
# The error is: 0
# païs.
# The actual count 3
# The approximate count by cms: 3
# The error is: 0
# Femme
# The actual count 3
# The approximate count by cms: 6
# The error is: 3
# espuse,
# The actual count 1
# The approximate count by cms: 1
# The error is: 0
# noble
# The actual count 2
# The approximate count by cms: 3
# The error is: 1
# sage,
# The actual count 3
# The approximate count by cms: 3
# The error is: 0
# haute
# The actual count 2
# The approximate count by cms: 4
# The error is: 2
# gent,
# The actual count 3
# The approximate count by cms: 3
# The error is: 0
# de
# The actual count 121
# The approximate count by cms: 122
# The error is: 1
# grant
# The actual count 30
# The approximate count by cms: 30
# The error is: 0
# parage.
# The actual count 1
# The approximate count by cms: 3
# The error is: 2
# E
# The actual count 127
# The approximate count by cms: 127
# The error is: 0
# vit
# The actual count 6
# The approximate count by cms: 7
# The error is: 1
# le
# The actual count 70
# The approximate count by cms: 71
# The error is: 1
# lit
# The actual count 6
# The approximate count by cms: 6
# The error is: 0
# a
# The actual count 79
# The approximate count by cms: 79
# The error is: 0
# pucele,
# The actual count 4
# The approximate count by cms: 4
# The error is: 0
# Mut
# The actual count 39
# The approximate count by cms: 40
# The error is: 1
# s'entr'amerent
# The actual count 1
# The approximate count by cms: 1
# The error is: 0
# lëaument
# The actual count 4
# The approximate count by cms: 5
# The error is: 1
# Mes
# The actual count 27
# The approximate count by cms: 32
# The error is: 5
# puis
# The actual count 5
# The approximate count by cms: 5
# The error is: 0
# avient
# The actual count 2
# The approximate count by cms: 13
# The error is: 11
# par
# The actual count 35
# The approximate count by cms: 35
# The error is: 0
# une
# The actual count 10
# The approximate count by cms: 12
# The error is: 2
# guere
# The actual count 4
# The approximate count by cms: 4
# The error is: 0
# Quë
# The actual count 10
# The approximate count by cms: 11
# The error is: 1
# il
# The actual count 66
# The approximate count by cms: 66
# The error is: 0
# alat
# The actual count 1
# The approximate count by cms: 5
# The error is: 4
# soudees
# The actual count 3
# The approximate count by cms: 9
# The error is: 6
# quere
# The actual count 2
# The approximate count by cms: 6
# The error is: 4
# :
# The actual count 3
# The approximate count by cms: 42
# The error is: 39
# Iloc
# The actual count 2
# The approximate count by cms: 3
# The error is: 1
# ama
# The actual count 3
# The approximate count by cms: 5
# The error is: 2
# meschine,
# The actual count 1
# The approximate count by cms: 1
# The error is: 0
# Fille
# The actual count 3
# The approximate count by cms: 4
# The error is: 1
# ert
# The actual count 5
# The approximate count by cms: 6
# The error is: 1
# rei
# The actual count 13
# The approximate count by cms: 13
# The error is: 0
# reïne.
# The actual count 1
# The approximate count by cms: 5
# The error is: 4
# Guilliadun
# The actual count 1
# The approximate count by cms: 1
# The error is: 0
# nun
# The actual count 3
# The approximate count by cms: 9
# The error is: 6
# El
# The actual count 6
# The approximate count by cms: 6
# The error is: 0
# rëaume
# The actual count 2
# The approximate count by cms: 3
# The error is: 1
# nen
# The actual count 7
# The approximate count by cms: 10
# The error is: 3
# plus
# The actual count 12
# The approximate count by cms: 24
# The error is: 12
# bele.
# The actual count 2
# The approximate count by cms: 3
# The error is: 1
# femme
# The actual count 18
# The approximate count by cms: 18
# The error is: 0
# resteit
# The actual count 1
# The approximate count by cms: 1
# The error is: 0
# apelee
# The actual count 1
# The approximate count by cms: 2
# The error is: 1
# Guildelüec
# The actual count 2
# The approximate count by cms: 2
# The error is: 0
# en
# The actual count 74
# The approximate count by cms: 74
# The error is: 0
# sa
# The actual count 45
# The approximate count by cms: 89
# The error is: 44
# cuntree.
# The actual count 3
# The approximate count by cms: 4
# The error is: 1
# D'eles
# The actual count 1
# The approximate count by cms: 1
# The error is: 0
# deus
# The actual count 2
# The approximate count by cms: 13
# The error is: 11
# ad
# The actual count 64
# The approximate count by cms: 65
# The error is: 1
# li
# The actual count 131
# The approximate count by cms: 131
# The error is: 0
# ha
# The actual count 1
# The approximate count by cms: 1
# The error is: 0
# Gualadun.
# The actual count 1
# The approximate count by cms: 1
# The error is: 0
# fu
# The actual count 28
# The approximate count by cms: 42
# The error is: 14
# primes
# The actual count 1
# The approximate count by cms: 1
# The error is: 0
# nomez,
# The actual count 1
# The approximate count by cms: 1
# The error is: 0
# ore
# The actual count 1
# The approximate count by cms: 1
# The error is: 0
# est
# The actual count 51
# The approximate count by cms: 52
# The error is: 1
# nuns
# The actual count 1
# The approximate count by cms: 7
# The error is: 6
# remüez,
# The actual count 1
# The approximate count by cms: 5
# The error is: 4
# Kar
# The actual count 11
# The approximate count by cms: 11
# The error is: 0
# des
# The actual count 9
# The approximate count by cms: 12
# The error is: 3
# dames
# The actual count 1
# The approximate count by cms: 1
# The error is: 0
# avenue.
# The actual count 1
# The approximate count by cms: 2
# The error is: 1
# L'aventure
# The actual count 3
# The approximate count by cms: 5
# The error is: 2
# dunt
# The actual count 2
# The approximate count by cms: 2
# The error is: 0
# lais
# The actual count 1
# The approximate count by cms: 2
# The error is: 1
# fu,
# The actual count 3
# The approximate count by cms: 4
# The error is: 1
# Si
# The actual count 35
# The approximate count by cms: 39
# The error is: 4
# avient,
# The actual count 1
# The approximate count by cms: 1
# The error is: 0
# vus
# The actual count 38
# The approximate count by cms: 41
# The error is: 3
# cunterai,
# The actual count 1
# The approximate count by cms: 3
# The error is: 2
# verité
# The actual count 1
# The approximate count by cms: 8
# The error is: 7
# dirrai.
# The actual count 1
# The approximate count by cms: 3
# The error is: 2
# aveit
# The actual count 19
# The approximate count by cms: 20
# The error is: 1
# seignur,
# The actual count 3
# The approximate count by cms: 3
# The error is: 0
# Reis
# The actual count 1
# The approximate count by cms: 1
# The error is: 0
# Brutaine
# The actual count 1
# The approximate count by cms: 5
# The error is: 4
# meinur,
# The actual count 1
# The approximate count by cms: 3
# The error is: 2
# Que
# The actual count 52
# The approximate count by cms: 53
# The error is: 1
# l'amot
# The actual count 3
# The approximate count by cms: 3
# The error is: 0
# cherisseit,
# The actual count 1
# The approximate count by cms: 3
# The error is: 2
# serveit.
# The actual count 1
# The approximate count by cms: 3
# The error is: 2
# U
# The actual count 14
# The approximate count by cms: 15
# The error is: 1
# que
# The actual count 45
# The approximate count by cms: 52
# The error is: 7
# reis
# The actual count 13
# The approximate count by cms: 17
# The error is: 4
# deüst
# The actual count 5
# The approximate count by cms: 6
# The error is: 1
# errer,
# The actual count 1
# The approximate count by cms: 1
# The error is: 0
# Il
# The actual count 17
# The approximate count by cms: 107
# The error is: 90
# tere
# The actual count 15
# The approximate count by cms: 15
# The error is: 0
# garder;
# The actual count 2
# The approximate count by cms: 2
# The error is: 0
# Pur
# The actual count 24
# The approximate count by cms: 28
# The error is: 4
# prüesce
# The actual count 1
# The approximate count by cms: 6
# The error is: 5
# retint.
# The actual count 1
# The approximate count by cms: 1
# The error is: 0
# tant
# The actual count 20
# The approximate count by cms: 23
# The error is: 3
# meuz
# The actual count 1
# The approximate count by cms: 1
# The error is: 0
# avint
# The actual count 1
# The approximate count by cms: 4
# The error is: 3
# Par
# The actual count 14
# The approximate count by cms: 14
# The error is: 0
# les
# The actual count 26
# The approximate count by cms: 26
# The error is: 0
# forez
# The actual count 1
# The approximate count by cms: 1
# The error is: 0
# poeit
# The actual count 2
# The approximate count by cms: 4
# The error is: 2
# chacier
# The actual count 1
# The approximate count by cms: 1
# The error is: 0
# N'i
# The actual count 3
# The approximate count by cms: 3
# The error is: 0
# forestier
# The actual count 1
# The approximate count by cms: 2
# The error is: 1
# Ki
# The actual count 7
# The approximate count by cms: 7
# The error is: 0
# cuntredire
# The actual count 1
# The approximate count by cms: 54
# The error is: 53
# osast
# The actual count 2
# The approximate count by cms: 6
# The error is: 4
# Ne
# The actual count 32
# The approximate count by cms: 32
# The error is: 0
# ja
# The actual count 4
# The approximate count by cms: 4
# The error is: 0
# feiz
# The actual count 5
# The approximate count by cms: 9
# The error is: 4
# grusçast.
# The actual count 1
# The approximate count by cms: 2
# The error is: 1
# l'envie
# The actual count 1
# The approximate count by cms: 3
# The error is: 2
# del
# The actual count 18
# The approximate count by cms: 18
# The error is: 0
# bien
# The actual count 17
# The approximate count by cms: 17
# The error is: 0
# lui,
# The actual count 4
# The approximate count by cms: 4
# The error is: 0
# sovent
# The actual count 3
# The approximate count by cms: 7
# The error is: 4
# d'autrui,
# The actual count 1
# The approximate count by cms: 2
# The error is: 1
# Esteit
# The actual count 2
# The approximate count by cms: 3
# The error is: 1
# sun
# The actual count 60
# The approximate count by cms: 60
# The error is: 0
# seignur
# The actual count 9
# The approximate count by cms: 11
# The error is: 2
# medlez
# The actual count 1
# The approximate count by cms: 1
# The error is: 0
# (e)
# The actual count 7
# The approximate count by cms: 8
# The error is: 1
# Empeirez
# The actual count 1
# The approximate count by cms: 1
# The error is: 0
# encusez,
# The actual count 1
# The approximate count by cms: 2
# The error is: 1
# curt
# The actual count 3
# The approximate count by cms: 3
# The error is: 0
# cungea
# The actual count 1
# The approximate count by cms: 1
# The error is: 0
# Sanz
# The actual count 1
# The approximate count by cms: 5
# The error is: 4
# qu'il
# The actual count 20
# The approximate count by cms: 24
# The error is: 4
# ne
# The actual count 76
# The approximate count by cms: 107
# The error is: 31
# l'areisuna.
# The actual count 1
# The approximate count by cms: 107
# The error is: 106
# Eliducs
# The actual count 1
# The approximate count by cms: 1
# The error is: 0
# saveit
# The actual count 3
# The approximate count by cms: 3
# The error is: 0
# pur
# The actual count 31
# The approximate count by cms: 31
# The error is: 0
# quei.
# The actual count 1
# The approximate count by cms: 1
# The error is: 0
# Soventefiez
# The actual count 1
# The approximate count by cms: 1
# The error is: 0
# requist
# The actual count 2
# The approximate count by cms: 2
# The error is: 0
# Qu'il
# The actual count 8
# The approximate count by cms: 8
# The error is: 0
# excundist
# The actual count 1
# The approximate count by cms: 1
# The error is: 0
# lui
# The actual count 41
# The approximate count by cms: 89
# The error is: 48
# preïst
# The actual count 1
# The approximate count by cms: 1
# The error is: 0
# losenge
# The actual count 1
# The approximate count by cms: 2
# The error is: 1
# creïst,
# The actual count 1
# The approximate count by cms: 3
# The error is: 2
# l'aveit
# The actual count 9
# The approximate count by cms: 12
# The error is: 3
# volenters
# The actual count 3
# The approximate count by cms: 3
# The error is: 0
# servi
# The actual count 2
# The approximate count by cms: 2
# The error is: 0
# respundi.
# The actual count 1
# The approximate count by cms: 2
# The error is: 1
# Quant
# The actual count 32
# The approximate count by cms: 32
# The error is: 0
# nel
# The actual count 7
# The approximate count by cms: 8
# The error is: 1
# volt
# The actual count 7
# The approximate count by cms: 7
# The error is: 0
# rien
# The actual count 7
# The approximate count by cms: 9
# The error is: 2
# oïr,
# The actual count 1
# The approximate count by cms: 5
# The error is: 4
# l'en
# The actual count 6
# The approximate count by cms: 6
# The error is: 0
# covient
# The actual count 2
# The approximate count by cms: 2
# The error is: 0
# idunc
# The actual count 1
# The approximate count by cms: 1
# The error is: 0
# partir.
# The actual count 1
# The approximate count by cms: 2
# The error is: 1
# A
# The actual count 44
# The approximate count by cms: 44
# The error is: 0
# mesun
# The actual count 1
# The approximate count by cms: 3
# The error is: 2
# alez,
# The actual count 2
# The approximate count by cms: 3
# The error is: 1
# tuz
# The actual count 10
# The approximate count by cms: 19
# The error is: 9
# ses
# The actual count 17
# The approximate count by cms: 17
# The error is: 0
# amis
# The actual count 3
# The approximate count by cms: 5
# The error is: 2
# mandez;
# The actual count 2
# The approximate count by cms: 5
# The error is: 3
# Del
# The actual count 7
# The approximate count by cms: 9
# The error is: 2
# lur
# The actual count 22
# The approximate count by cms: 22
# The error is: 0
# mustra
# The actual count 2
# The approximate count by cms: 3
# The error is: 1
# l'ire
# The actual count 1
# The approximate count by cms: 2
# The error is: 1
# vers
# The actual count 2
# The approximate count by cms: 3
# The error is: 1
# poeir,
# The actual count 1
# The approximate count by cms: 3
# The error is: 2
# Ja
# The actual count 4
# The approximate count by cms: 4
# The error is: 0
# maugré
# The actual count 1
# The approximate count by cms: 1
# The error is: 0
# aveir.
# The actual count 1
# The approximate count by cms: 2
# The error is: 1
# Li
# The actual count 25
# The approximate count by cms: 25
# The error is: 0
# vileins
# The actual count 1
# The approximate count by cms: 3
# The error is: 2
# dit
# The actual count 6
# The approximate count by cms: 6
# The error is: 0
# reprover,
# The actual count 1
# The approximate count by cms: 16
# The error is: 15
# tencë
# The actual count 1
# The approximate count by cms: 3
# The error is: 2
# charïer,
# The actual count 1
# The approximate count by cms: 4
# The error is: 3
# amur
# The actual count 4
# The approximate count by cms: 8
# The error is: 4
# deeignur
# The actual count 1
# The approximate count by cms: 1
# The error is: 0
# n'est
# The actual count 3
# The approximate count by cms: 3
# The error is: 0
# pas
# The actual count 6
# The approximate count by cms: 6
# The error is: 0
# fiez.
# The actual count 1
# The approximate count by cms: 2
# The error is: 1
# Sil
# The actual count 1
# The approximate count by cms: 1
# The error is: 0
# sages
# The actual count 3
# The approximate count by cms: 12
# The error is: 9
# vedzïez
# The actual count 1
# The approximate count by cms: 3
# The error is: 2
# lëauté
# The actual count 2
# The approximate count by cms: 3
# The error is: 1
# tient
# The actual count 3
# The approximate count by cms: 6
# The error is: 3
# Envers
# The actual count 1
# The approximate count by cms: 1
# The error is: 0
# bons
# The actual count 2
# The approximate count by cms: 2
# The error is: 0
# veisins
# The actual count 1
# The approximate count by cms: 10
# The error is: 9
# amur.
# The actual count 1
# The approximate count by cms: 1
# The error is: 0
# païs
# The actual count 7
# The approximate count by cms: 9
# The error is: 2
# arester,
# The actual count 1
# The approximate count by cms: 1
# The error is: 0
# Ainz
# The actual count 7
# The approximate count by cms: 8
# The error is: 1
# passera,
# The actual count 1
# The approximate count by cms: 4
# The error is: 3
# dit,
# The actual count 3
# The approximate count by cms: 3
# The error is: 0
# mer,
# The actual count 5
# The approximate count by cms: 5
# The error is: 0
# Al
# The actual count 10
# The approximate count by cms: 11
# The error is: 1
# Loengre
# The actual count 1
# The approximate count by cms: 1
# The error is: 0
# ira,
# The actual count 2
# The approximate count by cms: 4
# The error is: 2
# Une
# The actual count 10
# The approximate count by cms: 10
# The error is: 0
# piece
# The actual count 2
# The approximate count by cms: 3
# The error is: 1
# se
# The actual count 30
# The approximate count by cms: 31
# The error is: 1
# deduira;
# The actual count 1
# The approximate count by cms: 1
# The error is: 0
# Sa
# The actual count 6
# The approximate count by cms: 7
# The error is: 1
# larra,
# The actual count 1
# The approximate count by cms: 4
# The error is: 3
# hummes
# The actual count 4
# The approximate count by cms: 5
# The error is: 1
# cumandera
# The actual count 1
# The approximate count by cms: 2
# The error is: 1
# gardent
# The actual count 1
# The approximate count by cms: 2
# The error is: 1
# tuit
# The actual count 1
# The approximate count by cms: 2
# The error is: 1
# ami
# The actual count 5
# The approximate count by cms: 7
# The error is: 2
# ensement.
# The actual count 2
# The approximate count by cms: 2
# The error is: 0
# cel
# The actual count 7
# The approximate count by cms: 8
# The error is: 1
# cunseil
# The actual count 14
# The approximate count by cms: 18
# The error is: 4
# s'est
# The actual count 9
# The approximate count by cms: 9
# The error is: 0
# arestez,
# The actual count 1
# The approximate count by cms: 3
# The error is: 2
# richement
# The actual count 1
# The approximate count by cms: 3
# The error is: 2
# aturnez.
# The actual count 1
# The approximate count by cms: 1
# The error is: 0
# furent
# The actual count 10
# The approximate count by cms: 10
# The error is: 0
# dolent
# The actual count 2
# The approximate count by cms: 3
# The error is: 1
# ke
# The actual count 16
# The approximate count by cms: 17
# The error is: 1
# eus
# The actual count 10
# The approximate count by cms: 10
# The error is: 0
# departi.
# The actual count 1
# The approximate count by cms: 1
# The error is: 0
# Dis
# The actual count 1
# The approximate count by cms: 2
# The error is: 1
# chevalers
# The actual count 3
# The approximate count by cms: 4
# The error is: 1
# od
# The actual count 25
# The approximate count by cms: 25
# The error is: 0
# sei
# The actual count 4
# The approximate count by cms: 4
# The error is: 0
# mena,
# The actual count 1
# The approximate count by cms: 1
# The error is: 0
# cunvea;
# The actual count 1
# The approximate count by cms: 2
# The error is: 1
# Forment
# The actual count 2
# The approximate count by cms: 3
# The error is: 1
# demeine
# The actual count 1
# The approximate count by cms: 2
# The error is: 1
# dolur
# The actual count 5
# The approximate count by cms: 5
# The error is: 0
# departie
# The actual count 1
# The approximate count by cms: 2
# The error is: 1
# (de)
# The actual count 1
# The approximate count by cms: 3
# The error is: 2
# l'aseürat
# The actual count 1
# The approximate count by cms: 3
# The error is: 2
# porterat
# The actual count 1
# The approximate count by cms: 1
# The error is: 0
# bone
# The actual count 9
# The approximate count by cms: 9
# The error is: 0
# fei.
# The actual count 3
# The approximate count by cms: 3
# The error is: 0
# departi
# The actual count 2
# The approximate count by cms: 2
# The error is: 0
# atant,
# The actual count 1
# The approximate count by cms: 7
# The error is: 6
# chemin
# The actual count 3
# The approximate count by cms: 3
# The error is: 0
# tut
# The actual count 24
# The approximate count by cms: 24
# The error is: 0
# avant
# The actual count 3
# The approximate count by cms: 3
# The error is: 0
# mer
# The actual count 4
# The approximate count by cms: 4
# The error is: 0
# vient,
# The actual count 1
# The approximate count by cms: 12
# The error is: 11
# passez,
# The actual count 1
# The approximate count by cms: 2
# The error is: 1
# Toteneis
# The actual count 1
# The approximate count by cms: 1
# The error is: 0
# arivez.
# The actual count 1
# The approximate count by cms: 3
# The error is: 2
# Plusurs
# The actual count 2
# The approximate count by cms: 4
# The error is: 2
# (i)
# The actual count 2
# The approximate count by cms: 3
# The error is: 1
# tere,
# The actual count 1
# The approximate count by cms: 13
# The error is: 12
# Entre
# The actual count 3
# The approximate count by cms: 3
# The error is: 0
# eurent
# The actual count 4
# The approximate count by cms: 4
# The error is: 0
# estrif
# The actual count 1
# The approximate count by cms: 1
# The error is: 0
# guere.
# The actual count 1
# The approximate count by cms: 1
# The error is: 0
# Vers
# The actual count 3
# The approximate count by cms: 3
# The error is: 0
# Excestrë
# The actual count 1
# The approximate count by cms: 5
# The error is: 4
# Maneit
# The actual count 1
# The approximate count by cms: 1
# The error is: 0
# hum
# The actual count 7
# The approximate count by cms: 9
# The error is: 2
# poëstis,
# The actual count 1
# The approximate count by cms: 4
# The error is: 3
# Vieuz
# The actual count 1
# The approximate count by cms: 1
# The error is: 0
# auntïen
# The actual count 2
# The approximate count by cms: 107
# The error is: 105
# esteit.
# The actual count 3
# The approximate count by cms: 6
# The error is: 3
# Karnel
# The actual count 1
# The approximate count by cms: 2
# The error is: 1
# heir
# The actual count 1
# The approximate count by cms: 3
# The error is: 2
# madle
# The actual count 1
# The approximate count by cms: 7
# The error is: 6
# fille
# The actual count 8
# The approximate count by cms: 9
# The error is: 1
# merïer.
# The actual count 1
# The approximate count by cms: 1
# The error is: 0
# l'il
# The actual count 1
# The approximate count by cms: 8
# The error is: 7
# doner
# The actual count 3
# The approximate count by cms: 4
# The error is: 1
# per,
# The actual count 1
# The approximate count by cms: 6
# The error is: 5
# cil
# The actual count 7
# The approximate count by cms: 7
# The error is: 0
# guerriot,
# The actual count 1
# The approximate count by cms: 1
# The error is: 0
# Tute
# The actual count 7
# The approximate count by cms: 7
# The error is: 0
# gastot.
# The actual count 1
# The approximate count by cms: 3
# The error is: 2
# chastel
# The actual count 5
# The approximate count by cms: 5
# The error is: 0
# enclos
# The actual count 1
# The approximate count by cms: 1
# The error is: 0
# el
# The actual count 6
# The approximate count by cms: 6
# The error is: 0
# os
# The actual count 1
# The approximate count by cms: 3
# The error is: 2
# cuntre
# The actual count 3
# The approximate count by cms: 3
# The error is: 0
# eissir
# The actual count 1
# The approximate count by cms: 1
# The error is: 0
# Estur
# The actual count 1
# The approximate count by cms: 2
# The error is: 1
# mellee
# The actual count 1
# The approximate count by cms: 5
# The error is: 4
# tenir.
# The actual count 1
# The approximate count by cms: 1
# The error is: 0
# oï
# The actual count 9
# The approximate count by cms: 10
# The error is: 1
# parler;
# The actual count 1
# The approximate count by cms: 5
# The error is: 4
# voleit
# The actual count 4
# The approximate count by cms: 4
# The error is: 0
# mes
# The actual count 5
# The approximate count by cms: 5
# The error is: 0
# vant
# The actual count 1
# The approximate count by cms: 3
# The error is: 2
# aler,
# The actual count 2
# The approximate count by cms: 2
# The error is: 0
# iloc
# The actual count 1
# The approximate count by cms: 3
# The error is: 2
# trovee
# The actual count 2
# The approximate count by cms: 2
# The error is: 0
# Remaner
# The actual count 1
# The approximate count by cms: 2
# The error is: 1
# ki
# The actual count 14
# The approximate count by cms: 16
# The error is: 2
# esteit
# The actual count 15
# The approximate count by cms: 16
# The error is: 1
# grevez
# The actual count 2
# The approximate count by cms: 3
# The error is: 1
# damagiez
# The actual count 2
# The approximate count by cms: 2
# The error is: 0
# encumbrez
# The actual count 2
# The approximate count by cms: 2
# The error is: 0
# Vodrat
# The actual count 1
# The approximate count by cms: 2
# The error is: 1
# aider
# The actual count 1
# The approximate count by cms: 1
# The error is: 0
# poeir
# The actual count 1
# The approximate count by cms: 1
# The error is: 0
# remaneir.
# The actual count 1
# The approximate count by cms: 2
# The error is: 1
# Ses
# The actual count 7
# The approximate count by cms: 7
# The error is: 0
# messages
# The actual count 3
# The approximate count by cms: 3
# The error is: 0
# i
# The actual count 23
# The approximate count by cms: 25
# The error is: 2
# enveia
# The actual count 1
# The approximate count by cms: 2
# The error is: 1
# lettres
# The actual count 1
# The approximate count by cms: 4
# The error is: 3
# manda
# The actual count 2
# The approximate count by cms: 3
# The error is: 1
# iert
# The actual count 2
# The approximate count by cms: 2
# The error is: 0
# eissuz
# The actual count 1
# The approximate count by cms: 1
# The error is: 0
# s'aïe
# The actual count 1
# The approximate count by cms: 2
# The error is: 1
# venuz
# The actual count 2
# The approximate count by cms: 7
# The error is: 5
# (re)mandast
# The actual count 1
# The approximate count by cms: 1
# The error is: 0
# pleisir,
# The actual count 3
# The approximate count by cms: 6
# The error is: 3
# s'il
# The actual count 4
# The approximate count by cms: 5
# The error is: 1
# retenir,
# The actual count 2
# The approximate count by cms: 3
# The error is: 1
# Cunduit
# The actual count 1
# The approximate count by cms: 2
# The error is: 1
# donast
# The actual count 1
# The approximate count by cms: 3
# The error is: 2
# Avant
# The actual count 2
# The approximate count by cms: 3
# The error is: 1
# ireit
# The actual count 2
# The approximate count by cms: 5
# The error is: 3
# quere.
# The actual count 1
# The approximate count by cms: 4
# The error is: 3
# messagers,
# The actual count 1
# The approximate count by cms: 1
# The error is: 0
# (mut)
# The actual count 1
# The approximate count by cms: 2
# The error is: 1
# chers
# The actual count 1
# The approximate count by cms: 9
# The error is: 8
# Sun
# The actual count 10
# The approximate count by cms: 11
# The error is: 1
# cunestable
# The actual count 3
# The approximate count by cms: 5
# The error is: 2
# apelez
# The actual count 1
# The approximate count by cms: 1
# The error is: 0
# hastivement
# The actual count 1
# The approximate count by cms: 1
# The error is: 0
# comandez
# The actual count 1
# The approximate count by cms: 1
# The error is: 0
# cunduit
# The actual count 2
# The approximate count by cms: 3
# The error is: 1
# appareillast
# The actual count 1
# The approximate count by cms: 2
# The error is: 1
# Ke
# The actual count 3
# The approximate count by cms: 4
# The error is: 1
# barun
# The actual count 1
# The approximate count by cms: 1
# The error is: 0
# amenast,
# The actual count 1
# The approximate count by cms: 3
# The error is: 2
# face
# The actual count 4
# The approximate count by cms: 4
# The error is: 0
# osteus
# The actual count 2
# The approximate count by cms: 2
# The error is: 0
# appareiller
# The actual count 1
# The approximate count by cms: 1
# The error is: 0
# puïssent
# The actual count 1
# The approximate count by cms: 12
# The error is: 11
# herberger,
# The actual count 1
# The approximate count by cms: 5
# The error is: 4
# Tant
# The actual count 16
# The approximate count by cms: 17
# The error is: 1
# livrer
# The actual count 1
# The approximate count by cms: 5
# The error is: 4
# rendre
# The actual count 1
# The approximate count by cms: 3
# The error is: 2
# Cum
# The actual count 6
# The approximate count by cms: 7
# The error is: 1
# codrunt
# The actual count 1
# The approximate count by cms: 3
# The error is: 2
# meis
# The actual count 1
# The approximate count by cms: 2
# The error is: 1
# despendre.
# The actual count 1
# The approximate count by cms: 3
# The error is: 2
# appareillez
# The actual count 1
# The approximate count by cms: 1
# The error is: 0
# Eliduc
# The actual count 24
# The approximate count by cms: 24
# The error is: 0
# enveiez.
# The actual count 1
# The approximate count by cms: 2
# The error is: 1
# honur
# The actual count 1
# The approximate count by cms: 2
# The error is: 1
# receüz,
# The actual count 1
# The approximate count by cms: 3
# The error is: 2
# venuz.
# The actual count 3
# The approximate count by cms: 4
# The error is: 1
# ostel
# The actual count 4
# The approximate count by cms: 4
# The error is: 0
# chiés
# The actual count 1
# The approximate count by cms: 5
# The error is: 4
# burgeis,
# The actual count 1
# The approximate count by cms: 6
# The error is: 5
# sagë
# The actual count 1
# The approximate count by cms: 2
# The error is: 1
# curteis
# The actual count 4
# The approximate count by cms: 4
# The error is: 0
# bele
# The actual count 3
# The approximate count by cms: 3
# The error is: 0
# chambre
# The actual count 4
# The approximate count by cms: 5
# The error is: 1
# encrutinee
# The actual count 1
# The approximate count by cms: 1
# The error is: 0
# ostes
# The actual count 1
# The approximate count by cms: 1
# The error is: 0
# delivree.
# The actual count 1
# The approximate count by cms: 1
# The error is: 0
# fist
# The actual count 9
# The approximate count by cms: 11
# The error is: 2
# servir
# The actual count 3
# The approximate count by cms: 4
# The error is: 1
# manger
# The actual count 2
# The approximate count by cms: 10
# The error is: 8
# feseit
# The actual count 3
# The approximate count by cms: 6
# The error is: 3
# venir
# The actual count 2
# The approximate count by cms: 3
# The error is: 1
# Les
# The actual count 6
# The approximate count by cms: 7
# The error is: 1
# mesaeisez
# The actual count 1
# The approximate count by cms: 1
# The error is: 0
# burc
# The actual count 1
# The approximate count by cms: 1
# The error is: 0
# erent
# The actual count 4
# The approximate count by cms: 5
# The error is: 1
# herbergez.
# The actual count 1
# The approximate count by cms: 1
# The error is: 0
# defendi
# The actual count 1
# The approximate count by cms: 2
# The error is: 1
# n'i
# The actual count 7
# The approximate count by cms: 9
# The error is: 2
# eüst
# The actual count 3
# The approximate count by cms: 3
# The error is: 0
# nul
# The actual count 8
# The approximate count by cms: 11
# The error is: 3
# quarante
# The actual count 1
# The approximate count by cms: 2
# The error is: 1
# jurs
# The actual count 9
# The approximate count by cms: 10
# The error is: 1
# primers
# The actual count 1
# The approximate count by cms: 4
# The error is: 3
# Ppreïst
# The actual count 1
# The approximate count by cms: 7
# The error is: 6
# livreisun
# The actual count 1
# The approximate count by cms: 3
# The error is: 2
# deners.
# The actual count 1
# The approximate count by cms: 2
# The error is: 1
# terz
# The actual count 1
# The approximate count by cms: 1
# The error is: 0
# jur
# The actual count 13
# The approximate count by cms: 16
# The error is: 3
# surjurné
# The actual count 1
# The approximate count by cms: 1
# The error is: 0
# criz
# The actual count 1
# The approximate count by cms: 6
# The error is: 5
# leva
# The actual count 2
# The approximate count by cms: 8
# The error is: 6
# cité
# The actual count 2
# The approximate count by cms: 5
# The error is: 3
# enemi
# The actual count 1
# The approximate count by cms: 2
# The error is: 1
# sunt
# The actual count 6
# The approximate count by cms: 6
# The error is: 0
# venu
# The actual count 1
# The approximate count by cms: 3
# The error is: 2
# cuntree
# The actual count 2
# The approximate count by cms: 2
# The error is: 0
# espandu
# The actual count 1
# The approximate count by cms: 5
# The error is: 4
# vodrunt
# The actual count 1
# The approximate count by cms: 3
# The error is: 2
# vile
# The actual count 3
# The approximate count by cms: 4
# The error is: 1
# asaillir
# The actual count 1
# The approximate count by cms: 3
# The error is: 2
# as
# The actual count 1
# The approximate count by cms: 3
# The error is: 2
# portes
# The actual count 2
# The approximate count by cms: 4
# The error is: 2
# venir.
# The actual count 2
# The approximate count by cms: 3
# The error is: 1
# noise
# The actual count 2
# The approximate count by cms: 9
# The error is: 7
# oïe
# The actual count 1
# The approximate count by cms: 1
# The error is: 0
# gent
# The actual count 5
# The approximate count by cms: 7
# The error is: 2
# esturdie.
# The actual count 1
# The approximate count by cms: 3
# The error is: 2
# armé,
# The actual count 1
# The approximate count by cms: 1
# The error is: 0
# atent,
# The actual count 2
# The approximate count by cms: 14
# The error is: 12
# cumpainuns
# The actual count 3
# The approximate count by cms: 3
# The error is: 0
# Quatorze
# The actual count 1
# The approximate count by cms: 4
# The error is: 3
# muntant
# The actual count 1
# The approximate count by cms: 2
# The error is: 1
# Ot
# The actual count 1
# The approximate count by cms: 1
# The error is: 0
# surjurnant
# The actual count 1
# The approximate count by cms: 2
# The error is: 1
# nafrez
# The actual count 2
# The approximate count by cms: 2
# The error is: 0
# prisuns
# The actual count 3
# The approximate count by cms: 3
# The error is: 0
# asez
# The actual count 2
# The approximate count by cms: 2
# The error is: 0
# Cil
# The actual count 13
# The approximate count by cms: 14
# The error is: 1
# virent
# The actual count 1
# The approximate count by cms: 1
# The error is: 0
# munter
# The actual count 2
# The approximate count by cms: 2
# The error is: 0
# vunt
# The actual count 1
# The approximate count by cms: 3
# The error is: 2
# armer,
# The actual count 1
# The approximate count by cms: 5
# The error is: 4
# Fors
# The actual count 6
# The approximate count by cms: 6
# The error is: 0
# porte
# The actual count 6
# The approximate count by cms: 6
# The error is: 0
# of
# The actual count 4
# The approximate count by cms: 7
# The error is: 3
# eissirent,
# The actual count 1
# The approximate count by cms: 1
# The error is: 0
# sumunse
# The actual count 1
# The approximate count by cms: 2
# The error is: 1
# atendirent.
# The actual count 1
# The approximate count by cms: 1
# The error is: 0
# "Sire,"
# The actual count 1
# The approximate count by cms: 6
# The error is: 5
# funt
# The actual count 4
# The approximate count by cms: 5
# The error is: 1
# il,
# The actual count 10
# The approximate count by cms: 11
# The error is: 1
# "od
# The actual count 1
# The approximate count by cms: 6
# The error is: 5
# irum
# The actual count 1
# The approximate count by cms: 1
# The error is: 0
# ferez
# The actual count 1
# The approximate count by cms: 1
# The error is: 0
# ferum!"
# The actual count 1
# The approximate count by cms: 3
# The error is: 2
# respunt:
# The actual count 3
# The approximate count by cms: 3
# The error is: 0
# "vostre
# The actual count 1
# The approximate count by cms: 3
# The error is: 2
# merci!
# The actual count 3
# The approximate count by cms: 6
# The error is: 3
# Avreit
# The actual count 1
# The approximate count by cms: 4
# The error is: 3
# ici
# The actual count 2
# The approximate count by cms: 2
# The error is: 0
# maupas
# The actual count 1
# The approximate count by cms: 2
# The error is: 1
# u
# The actual count 12
# The approximate count by cms: 13
# The error is: 1
# destreit
# The actual count 2
# The approximate count by cms: 6
# The error is: 4
# seüst,
# The actual count 1
# The approximate count by cms: 4
# The error is: 3
# l'um
# The actual count 2
# The approximate count by cms: 3
# The error is: 1
# encumbrer
# The actual count 1
# The approximate count by cms: 1
# The error is: 0
# peüst
# The actual count 2
# The approximate count by cms: 4
# The error is: 2
# ?
# The actual count 1
# The approximate count by cms: 17
# The error is: 16
# nus
# The actual count 7
# The approximate count by cms: 8
# The error is: 1
# atendums,
# The actual count 1
# The approximate count by cms: 3
# The error is: 2
# Peot
# The actual count 3
# The approximate count by cms: 5
# The error is: 2
# estre,
# The actual count 3
# The approximate count by cms: 5
# The error is: 2
# justerums
# The actual count 1
# The approximate count by cms: 2
# The error is: 1
# n'ateint
# The actual count 1
# The approximate count by cms: 1
# The error is: 0
# espleit,
# The actual count 2
# The approximate count by cms: 2
# The error is: 0
# autre
# The actual count 6
# The approximate count by cms: 7
# The error is: 1
# sav(r)eit."
# The actual count 1
# The approximate count by cms: 1
# The error is: 0
# dïent:
# The actual count 1
# The approximate count by cms: 1
# The error is: 0
# "sire,
# The actual count 1
# The approximate count by cms: 1
# The error is: 0
# fei,
# The actual count 4
# The approximate count by cms: 6
# The error is: 2
# Pres
# The actual count 4
# The approximate count by cms: 5
# The error is: 1
# bois
# The actual count 7
# The approximate count by cms: 10
# The error is: 3
# ristei
# The actual count 1
# The approximate count by cms: 1
# The error is: 0
# estreite
# The actual count 1
# The approximate count by cms: 4
# The error is: 3
# charriere,
# The actual count 1
# The approximate count by cms: 1
# The error is: 0
# unt
# The actual count 7
# The approximate count by cms: 8
# The error is: 1
# repeirent
# The actual count 1
# The approximate count by cms: 3
# The error is: 2
# ariere
# The actual count 2
# The approximate count by cms: 4
# The error is: 2
# avrunt
# The actual count 2
# The approximate count by cms: 3
# The error is: 1
# fet
# The actual count 25
# The approximate count by cms: 27
# The error is: 2
# eschec,
# The actual count 1
# The approximate count by cms: 2
# The error is: 1
# returnerunt
# The actual count 1
# The approximate count by cms: 1
# The error is: 0
# ilec;
# The actual count 1
# The approximate count by cms: 1
# The error is: 0
# Desarmez
# The actual count 1
# The approximate count by cms: 2
# The error is: 1
# sur
# The actual count 8
# The approximate count by cms: 9
# The error is: 1
# palefrez
# The actual count 1
# The approximate count by cms: 2
# The error is: 1
# S'en
# The actual count 1
# The approximate count by cms: 3
# The error is: 2
# revunt
# The actual count 1
# The approximate count by cms: 2
# The error is: 1
# (il)
# The actual count 3
# The approximate count by cms: 5
# The error is: 2
# soventefez,
# The actual count 1
# The approximate count by cms: 1
# The error is: 0
# mettent
# The actual count 1
# The approximate count by cms: 5
# The error is: 4
# aventure
# The actual count 1
# The approximate count by cms: 4
# The error is: 3
# Cume
# The actual count 1
# The approximate count by cms: 2
# The error is: 1
# murir
# The actual count 2
# The approximate count by cms: 2
# The error is: 0
# dreiture".
# The actual count 1
# The approximate count by cms: 2
# The error is: 1
# Bien
# The actual count 7
# The approximate count by cms: 12
# The error is: 5
# tost
# The actual count 3
# The approximate count by cms: 3
# The error is: 0
# purreit
# The actual count 1
# The approximate count by cms: 1
# The error is: 0
# damagier
# The actual count 2
# The approximate count by cms: 3
# The error is: 1
# laidier
# The actual count 1
# The approximate count by cms: 2
# The error is: 1
# empeirier.
# The actual count 1
# The approximate count by cms: 2
# The error is: 1
# dit:
# The actual count 4
# The approximate count by cms: 5
# The error is: 1
# "amis,
# The actual count 1
# The approximate count by cms: 1
# The error is: 0
# meie
# The actual count 1
# The approximate count by cms: 1
# The error is: 0
# fei
# The actual count 4
# The approximate count by cms: 8
# The error is: 4
# plevis
# The actual count 1
# The approximate count by cms: 1
# The error is: 0
# tel
# The actual count 5
# The approximate count by cms: 6
# The error is: 1
# liu
# The actual count 2
# The approximate count by cms: 2
# The error is: 0
# va
# The actual count 3
# The approximate count by cms: 3
# The error is: 0
# suvent
# The actual count 4
# The approximate count by cms: 5
# The error is: 1
# quide
# The actual count 2
# The approximate count by cms: 4
# The error is: 2
# perdre
# The actual count 1
# The approximate count by cms: 4
# The error is: 3
# scïent,
# The actual count 1
# The approximate count by cms: 5
# The error is: 4
# gueres
# The actual count 2
# The approximate count by cms: 2
# The error is: 0
# gaainera
# The actual count 1
# The approximate count by cms: 1
# The error is: 0
# Në
# The actual count 3
# The approximate count by cms: 4
# The error is: 1
# pris
# The actual count 7
# The approximate count by cms: 8
# The error is: 1
# muntera.
# The actual count 1
# The approximate count by cms: 34
# The error is: 33
# estes
# The actual count 4
# The approximate count by cms: 6
# The error is: 2
# rei,
# The actual count 4
# The approximate count by cms: 5
# The error is: 1
# devez
# The actual count 1
# The approximate count by cms: 1
# The error is: 0
# porter
# The actual count 2
# The approximate count by cms: 4
# The error is: 2
# Venez
# The actual count 1
# The approximate count by cms: 2
# The error is: 1
# mei
# The actual count 7
# The approximate count by cms: 9
# The error is: 2
# j'irai,
# The actual count 1
# The approximate count by cms: 3
# The error is: 2
# fetes
# The actual count 1
# The approximate count by cms: 2
# The error is: 1
# ferai!
# The actual count 1
# The approximate count by cms: 3
# The error is: 2
# Jo
# The actual count 4
# The approximate count by cms: 5
# The error is: 1
# asseür
# The actual count 1
# The approximate count by cms: 1
# The error is: 0
# lëaument,
# The actual count 1
# The approximate count by cms: 1
# The error is: 0
# avrez
# The actual count 2
# The approximate count by cms: 3
# The error is: 1
# encumbrement,
# The actual count 1
# The approximate count by cms: 2
# The error is: 1
# atant
# The actual count 1
# The approximate count by cms: 2
# The error is: 1
# cume
# The actual count 2
# The approximate count by cms: 2
# The error is: 0
# jo
# The actual count 3
# The approximate count by cms: 6
# The error is: 3
# aidier.
# The actual count 1
# The approximate count by cms: 2
# The error is: 1
# poüm
# The actual count 2
# The approximate count by cms: 2
# The error is: 0
# gaainier,
# The actual count 1
# The approximate count by cms: 21
# The error is: 20
# Ceo
# The actual count 5
# The approximate count by cms: 5
# The error is: 0
# turné
# The actual count 1
# The approximate count by cms: 1
# The error is: 0
# noz
# The actual count 1
# The approximate count by cms: 2
# The error is: 1
# enemis."
# The actual count 1
# The approximate count by cms: 1
# The error is: 0
# Icil
# The actual count 1
# The approximate count by cms: 2
# The error is: 1
# seütré,
# The actual count 1
# The approximate count by cms: 1
# The error is: 0
# l'unt
# The actual count 1
# The approximate count by cms: 1
# The error is: 0
# mené;
# The actual count 1
# The approximate count by cms: 1
# The error is: 0
# enbuschié,
# The actual count 1
# The approximate count by cms: 9
# The error is: 8
# repeirié.
# The actual count 1
# The approximate count by cms: 2
# The error is: 1
# mustré
# The actual count 3
# The approximate count by cms: 41
# The error is: 38
# enseignié
# The actual count 1
# The approximate count by cms: 1
# The error is: 0
# devisé
# The actual count 1
# The approximate count by cms: 7
# The error is: 6
# queil
# The actual count 2
# The approximate count by cms: 3
# The error is: 1
# manere
# The actual count 2
# The approximate count by cms: 3
# The error is: 1
# puindrunt
# The actual count 1
# The approximate count by cms: 2
# The error is: 1
# escrïerunt.
# The actual count 1
# The approximate count by cms: 3
# The error is: 2
# entrez,
# The actual count 1
# The approximate count by cms: 1
# The error is: 0
# escrïez.
# The actual count 1
# The approximate count by cms: 3
# The error is: 2
# Tuz
# The actual count 4
# The approximate count by cms: 4
# The error is: 0
# apela
# The actual count 1
# The approximate count by cms: 1
# The error is: 0
# cumpainuns,
# The actual count 1
# The approximate count by cms: 1
# The error is: 0
# faire
# The actual count 3
# The approximate count by cms: 4
# The error is: 1
# sumuns.
# The actual count 1
# The approximate count by cms: 1
# The error is: 0
# ferirent
# The actual count 1
# The approximate count by cms: 6
# The error is: 5
# durement
# The actual count 4
# The approximate count by cms: 17
# The error is: 13
# (ne)
# The actual count 1
# The approximate count by cms: 1
# The error is: 0
# Nes
# The actual count 1
# The approximate count by cms: 1
# The error is: 0
# esparnierent
# The actual count 1
# The approximate count by cms: 1
# The error is: 0
# nïent.
# The actual count 1
# The approximate count by cms: 1
# The error is: 0
# esteient
# The actual count 3
# The approximate count by cms: 3
# The error is: 0
# esbaï,
# The actual count 1
# The approximate count by cms: 1
# The error is: 0
# Tost
# The actual count 1
# The approximate count by cms: 1
# The error is: 0
# rut
# The actual count 1
# The approximate count by cms: 3
# The error is: 2
# departi,
# The actual count 1
# The approximate count by cms: 1
# The error is: 0
# poi
# The actual count 5
# The approximate count by cms: 5
# The error is: 0
# hure
# The actual count 1
# The approximate count by cms: 4
# The error is: 3
# vencu.
# The actual count 1
# The approximate count by cms: 1
# The error is: 0
# Lur
# The actual count 4
# The approximate count by cms: 4
# The error is: 0
# retenu
# The actual count 5
# The approximate count by cms: 5
# The error is: 0
# autres
# The actual count 4
# The approximate count by cms: 4
# The error is: 0
# chevaliers
# The actual count 2
# The approximate count by cms: 19
# The error is: 17
# Tuit
# The actual count 1
# The approximate count by cms: 1
# The error is: 0
# chargent
# The actual count 1
# The approximate count by cms: 1
# The error is: 0
# esquïers
# The actual count 2
# The approximate count by cms: 32
# The error is: 30
# Vint
# The actual count 1
# The approximate count by cms: 1
# The error is: 0
# cinc
# The actual count 2
# The approximate count by cms: 2
# The error is: 0
# ça,
# The actual count 1
# The approximate count by cms: 1
# The error is: 0
# Trente
# The actual count 3
# The approximate count by cms: 3
# The error is: 0
# pristrent
# The actual count 2
# The approximate count by cms: 2
# The error is: 0
# ceus
# The actual count 4
# The approximate count by cms: 107
# The error is: 103
# la.
# The actual count 1
# The approximate count by cms: 1
# The error is: 0
# herneis
# The actual count 1
# The approximate count by cms: 2
# The error is: 1
# Merveillus
# The actual count 1
# The approximate count by cms: 1
# The error is: 0
# gaain
# The actual count 1
# The approximate count by cms: 1
# The error is: 0
# feit.
# The actual count 1
# The approximate count by cms: 1
# The error is: 0
# Ariere
# The actual count 2
# The approximate count by cms: 2
# The error is: 0
# s'en
# The actual count 19
# The approximate count by cms: 20
# The error is: 1
# (re)vunt
# The actual count 1
# The approximate count by cms: 4
# The error is: 3
# lié:
# The actual count 1
# The approximate count by cms: 1
# The error is: 0
# aveient
# The actual count 2
# The approximate count by cms: 3
# The error is: 1
# espleitié.
# The actual count 1
# The approximate count by cms: 2
# The error is: 1
# tur,
# The actual count 1
# The approximate count by cms: 2
# The error is: 1
# poür;
# The actual count 1
# The approximate count by cms: 1
# The error is: 0
# forment
# The actual count 1
# The approximate count by cms: 1
# The error is: 0
# pleigneit,
# The actual count 1
# The approximate count by cms: 2
# The error is: 1
# quidout
# The actual count 1
# The approximate count by cms: 1
# The error is: 0
# (si)
# The actual count 1
# The approximate count by cms: 1
# The error is: 0
# cremeit
# The actual count 1
# The approximate count by cms: 1
# The error is: 0
# eit
# The actual count 1
# The approximate count by cms: 1
# The error is: 0
# mis
# The actual count 4
# The approximate count by cms: 5
# The error is: 1
# abandun
# The actual count 1
# The approximate count by cms: 1
# The error is: 0
# traïsun.
# The actual count 1
# The approximate count by cms: 122
# The error is: 121
# vienent
# The actual count 1
# The approximate count by cms: 2
# The error is: 1
# aruté
# The actual count 1
# The approximate count by cms: 3
# The error is: 2
# Tut
# The actual count 7
# The approximate count by cms: 10
# The error is: 3
# chargié
# The actual count 1
# The approximate count by cms: 2
# The error is: 1
# trussé.
# The actual count 1
# The approximate count by cms: 2
# The error is: 1
# revenir
# The actual count 1
# The approximate count by cms: 2
# The error is: 1
# n'esteient
# The actual count 1
# The approximate count by cms: 3
# The error is: 2
# fors
# ...
# The error is: 1
# musteile
# The actual count 1
# The approximate count by cms: 1
# The error is: 0
# curant,
# The actual count 1
# The approximate count by cms: 1
# The error is: 0
# eissue,
# The actual count 2
# The approximate count by cms: 2
# The error is: 0
# ferue
# The actual count 1
# The approximate count by cms: 1
# The error is: 0
# passa;
# The actual count 1
# The approximate count by cms: 2
# The error is: 1
# bastun
# The actual count 1
# The approximate count by cms: 1
# The error is: 0
# tint
# The actual count 1
# The approximate count by cms: 1
# The error is: 0
# tua.
# The actual count 1
# The approximate count by cms: 1
# The error is: 0
# l'eire
# The actual count 1
# The approximate count by cms: 1
# The error is: 0
# getee.
# The actual count 1
# The approximate count by cms: 2
# The error is: 1
# demura
# The actual count 1
# The approximate count by cms: 3
# The error is: 2
# loëe,
# The actual count 1
# The approximate count by cms: 1
# The error is: 0
# cumpaine
# The actual count 2
# The approximate count by cms: 4
# The error is: 2
# acurrut,
# The actual count 1
# The approximate count by cms: 2
# The error is: 1
# jut;
# The actual count 1
# The approximate count by cms: 4
# The error is: 3
# Entur
# The actual count 1
# The approximate count by cms: 1
# The error is: 0
# teste
# The actual count 1
# The approximate count by cms: 1
# The error is: 0
# marcha.
# The actual count 1
# The approximate count by cms: 2
# The error is: 1
# pot
# The actual count 1
# The approximate count by cms: 3
# The error is: 2
# lever,
# The actual count 1
# The approximate count by cms: 2
# The error is: 1
# Semblant
# The actual count 1
# The approximate count by cms: 3
# The error is: 2
# herbes
# The actual count 1
# The approximate count by cms: 1
# The error is: 0
# venue;
# The actual count 1
# The approximate count by cms: 1
# The error is: 0
# denz
# The actual count 1
# The approximate count by cms: 1
# The error is: 0
# flur
# The actual count 2
# The approximate count by cms: 2
# The error is: 0
# vermeille
# The actual count 1
# The approximate count by cms: 3
# The error is: 2
# colur;
# The actual count 1
# The approximate count by cms: 1
# The error is: 0
# Hastivement
# The actual count 1
# The approximate count by cms: 1
# The error is: 0
# reveit
# The actual count 1
# The approximate count by cms: 1
# The error is: 0
# ariere;
# The actual count 1
# The approximate count by cms: 2
# The error is: 1
# mise,
# The actual count 1
# The approximate count by cms: 1
# The error is: 0
# vadlez
# The actual count 1
# The approximate count by cms: 1
# The error is: 0
# laveit
# The actual count 1
# The approximate count by cms: 2
# The error is: 1
# ocise,
# The actual count 1
# The approximate count by cms: 2
# The error is: 1
# es
# The actual count 1
# The approximate count by cms: 2
# The error is: 1
# l'ure
# The actual count 1
# The approximate count by cms: 5
# The error is: 4
# revescue.
# The actual count 1
# The approximate count by cms: 2
# The error is: 1
# aparceüe;
# The actual count 1
# The approximate count by cms: 4
# The error is: 3
# crie:
# The actual count 1
# The approximate count by cms: 1
# The error is: 0
# "Retien
# The actual count 1
# The approximate count by cms: 12
# The error is: 11
# la!
# The actual count 1
# The approximate count by cms: 3
# The error is: 2
# Getez,
# The actual count 1
# The approximate count by cms: 2
# The error is: 1
# franc
# The actual count 1
# The approximate count by cms: 1
# The error is: 0
# humme,
# The actual count 1
# The approximate count by cms: 3
# The error is: 2
# ira!"
# The actual count 1
# The approximate count by cms: 2
# The error is: 1
# geta,
# The actual count 1
# The approximate count by cms: 1
# The error is: 0
# feri,
# The actual count 1
# The approximate count by cms: 1
# The error is: 0
# floret(e)
# The actual count 1
# The approximate count by cms: 1
# The error is: 0
# cheï.
# The actual count 1
# The approximate count by cms: 3
# The error is: 2
# lieve,
# The actual count 1
# The approximate count by cms: 1
# The error is: 0
# Meteit
# The actual count 1
# The approximate count by cms: 4
# The error is: 3
# petitet
# The actual count 1
# The approximate count by cms: 1
# The error is: 0
# revint
# The actual count 2
# The approximate count by cms: 2
# The error is: 0
# suspira;
# The actual count 1
# The approximate count by cms: 1
# The error is: 0
# parla,
# The actual count 1
# The approximate count by cms: 11
# The error is: 10
# "Deu,"
# The actual count 1
# The approximate count by cms: 1
# The error is: 0
# "tant
# The actual count 1
# The approximate count by cms: 1
# The error is: 0
# dormi!"
# The actual count 1
# The approximate count by cms: 1
# The error is: 0
# cumençat
# The actual count 1
# The approximate count by cms: 1
# The error is: 0
# mercïer.
# The actual count 1
# The approximate count by cms: 3
# The error is: 2
# demande
# The actual count 1
# The approximate count by cms: 9
# The error is: 8
# diseit:
# The actual count 1
# The approximate count by cms: 5
# The error is: 4
# Logres
# The actual count 1
# The approximate count by cms: 1
# The error is: 0
# nee,
# The actual count 1
# The approximate count by cms: 1
# The error is: 0
# amé
# The actual count 1
# The approximate count by cms: 1
# The error is: 0
# chevalier,
# The actual count 1
# The approximate count by cms: 2
# The error is: 1
# soudeer;
# The actual count 1
# The approximate count by cms: 4
# The error is: 3
# Ensemble
# The actual count 5
# The approximate count by cms: 7
# The error is: 2
# amena.
# The actual count 1
# The approximate count by cms: 9
# The error is: 8
# Peché
# The actual count 1
# The approximate count by cms: 1
# The error is: 0
# m'enginna:
# The actual count 1
# The approximate count by cms: 11
# The error is: 10
# espuse;
# The actual count 1
# The approximate count by cms: 1
# The error is: 0
# paumer.
# The actual count 1
# The approximate count by cms: 1
# The error is: 0
# Vileinement
# The actual count 1
# The approximate count by cms: 2
# The error is: 1
# descunseillee
# The actual count 1
# The approximate count by cms: 1
# The error is: 0
# M'ad
# The actual count 1
# The approximate count by cms: 3
# The error is: 2
# laissee;
# The actual count 1
# The approximate count by cms: 1
# The error is: 0
# Trahi(e)
# The actual count 1
# The approximate count by cms: 1
# The error is: 0
# m'ad,
# The actual count 1
# The approximate count by cms: 2
# The error is: 1
# deit.
# The actual count 1
# The approximate count by cms: 4
# The error is: 3
# fole
# The actual count 1
# The approximate count by cms: 1
# The error is: 0
# creit."
# The actual count 1
# The approximate count by cms: 11
# The error is: 10
# respunt,
# The actual count 1
# The approximate count by cms: 2
# The error is: 1
# "N'ad
# The actual count 1
# The approximate count by cms: 2
# The error is: 1
# vivant
# The actual count 1
# The approximate count by cms: 3
# The error is: 2
# munt
# The actual count 1
# The approximate count by cms: 2
# The error is: 1
# aveir;
# The actual count 1
# The approximate count by cms: 4
# The error is: 3
# veir.
# The actual count 1
# The approximate count by cms: 2
# The error is: 1
# morte,
# The actual count 1
# The approximate count by cms: 2
# The error is: 1
# descunforte.
# The actual count 1
# The approximate count by cms: 1
# The error is: 0
# Chescun
# The actual count 1
# The approximate count by cms: 2
# The error is: 1
# regardee;
# The actual count 1
# The approximate count by cms: 2
# The error is: 1
# trova
# The actual count 1
# The approximate count by cms: 1
# The error is: 0
# pasmee.
# The actual count 1
# The approximate count by cms: 23
# The error is: 22
# spuse
# The actual count 1
# The approximate count by cms: 2
# The error is: 1
# vereiment,
# The actual count 1
# The approximate count by cms: 2
# The error is: 1
# dolent;
# The actual count 1
# The approximate count by cms: 1
# The error is: 0
# menot
# The actual count 1
# The approximate count by cms: 5
# The error is: 4
# Saveir
# The actual count 1
# The approximate count by cms: 1
# The error is: 0
# voleie
# The actual count 1
# The approximate count by cms: 2
# The error is: 1
# alot:
# The actual count 1
# The approximate count by cms: 1
# The error is: 0
# veinc,
# The actual count 1
# The approximate count by cms: 1
# The error is: 0
# trovai.
# The actual count 1
# The approximate count by cms: 4
# The error is: 3
# vive
# The actual count 2
# The approximate count by cms: 2
# The error is: 0
# merrai
# The actual count 1
# The approximate count by cms: 2
# The error is: 1
# rendrai.
# The actual count 1
# The approximate count by cms: 1
# The error is: 0
# quite
# The actual count 1
# The approximate count by cms: 1
# The error is: 0
# clamer,
# The actual count 1
# The approximate count by cms: 1
# The error is: 0
# chef
# The actual count 1
# The approximate count by cms: 4
# The error is: 3
# veler."
# The actual count 1
# The approximate count by cms: 4
# The error is: 3
# confortee
# The actual count 1
# The approximate count by cms: 5
# The error is: 4
# menee.
# The actual count 1
# The approximate count by cms: 2
# The error is: 1
# vallet
# The actual count 1
# The approximate count by cms: 2
# The error is: 1
# enveié.
# The actual count 1
# The approximate count by cms: 1
# The error is: 0
# errat
# The actual count 1
# The approximate count by cms: 1
# The error is: 0
# Avenantment
# The actual count 1
# The approximate count by cms: 2
# The error is: 1
# salua,
# The actual count 1
# The approximate count by cms: 1
# The error is: 0
# cunte.
# The actual count 1
# The approximate count by cms: 9
# The error is: 8
# munte,
# The actual count 1
# The approximate count by cms: 2
# The error is: 1
# atendi
# The actual count 1
# The approximate count by cms: 2
# The error is: 1
# cumpainun.
# The actual count 1
# The approximate count by cms: 5
# The error is: 4
# meisun.
# The actual count 2
# The approximate count by cms: 3
# The error is: 1
# Ducement
# The actual count 1
# The approximate count by cms: 2
# The error is: 1
# mercie.
# The actual count 1
# The approximate count by cms: 4
# The error is: 3
# haitiez,
# The actual count 1
# The approximate count by cms: 2
# The error is: 1
# liez;
# The actual count 1
# The approximate count by cms: 1
# The error is: 0
# ducement;
# The actual count 1
# The approximate count by cms: 11
# The error is: 10
# grant.
# The actual count 1
# The approximate count by cms: 5
# The error is: 4
# mis;
# The actual count 1
# The approximate count by cms: 3
# The error is: 2
# Cungé
# The actual count 1
# The approximate count by cms: 1
# The error is: 0
# rové
# The actual count 1
# The approximate count by cms: 1
# The error is: 0
# Nunein
# The actual count 1
# The approximate count by cms: 2
# The error is: 1
# servir;
# The actual count 1
# The approximate count by cms: 4
# The error is: 3
# doint
# The actual count 1
# The approximate count by cms: 4
# The error is: 3
# partie,
# The actual count 1
# The approximate count by cms: 4
# The error is: 3
# abeïe;
# The actual count 1
# The approximate count by cms: 11
# The error is: 10
# prenge
# The actual count 1
# The approximate count by cms: 3
# The error is: 2
# eime
# The actual count 1
# The approximate count by cms: 1
# The error is: 0
# tant,
# The actual count 1
# The approximate count by cms: 2
# The error is: 1
# avenant
# The actual count 1
# The approximate count by cms: 3
# The error is: 2
# espuses
# The actual count 1
# The approximate count by cms: 2
# The error is: 1
# meintenir,
# The actual count 1
# The approximate count by cms: 2
# The error is: 1
# lei
# The actual count 1
# The approximate count by cms: 1
# The error is: 0
# cunsentir.
# The actual count 1
# The approximate count by cms: 1
# The error is: 0
# otrïé
# The actual count 1
# The approximate count by cms: 1
# The error is: 0
# doné:
# The actual count 1
# The approximate count by cms: 3
# The error is: 2
# volunté
# The actual count 1
# The approximate count by cms: 1
# The error is: 0
# durra.
# The actual count 1
# The approximate count by cms: 1
# The error is: 0
# boscage
# The actual count 1
# The approximate count by cms: 1
# The error is: 0
# l'hermitage
# The actual count 1
# The approximate count by cms: 4
# The error is: 3
# meisuns
# The actual count 1
# The approximate count by cms: 1
# The error is: 0
# edifier;
# The actual count 1
# The approximate count by cms: 4
# The error is: 3
# aveir:
# The actual count 1
# The approximate count by cms: 1
# The error is: 0
# avrat
# The actual count 1
# The approximate count by cms: 1
# The error is: 0
# aturner,
# The actual count 1
# The approximate count by cms: 2
# The error is: 1
# chief
# The actual count 1
# The approximate count by cms: 1
# The error is: 0
# veler,
# The actual count 1
# The approximate count by cms: 5
# The error is: 4
# s'ordrë
# The actual count 1
# The approximate count by cms: 2
# The error is: 1
# establi.
# The actual count 1
# The approximate count by cms: 1
# The error is: 0
# prise;
# The actual count 1
# The approximate count by cms: 1
# The error is: 0
# feste
# The actual count 1
# The approximate count by cms: 2
# The error is: 1
# demenee
# The actual count 1
# The approximate count by cms: 3
# The error is: 2
# espusee.
# The actual count 1
# The approximate count by cms: 1
# The error is: 0
# vesquirent
# The actual count 1
# The approximate count by cms: 2
# The error is: 1
# meint
# The actual count 1
# The approximate count by cms: 1
# The error is: 0
# jur,
# The actual count 1
# The approximate count by cms: 5
# The error is: 4
# parfit'amur.
# The actual count 1
# The approximate count by cms: 1
# The error is: 0
# Granz
# The actual count 1
# The approximate count by cms: 1
# The error is: 0
# aumoines
# The actual count 1
# The approximate count by cms: 2
# The error is: 1
# granz
# The actual count 1
# The approximate count by cms: 1
# The error is: 0
# firent,
# The actual count 1
# The approximate count by cms: 4
# The error is: 3
# cunvertirent.
# The actual count 1
# The approximate count by cms: 7
# The error is: 6
# esgart
# The actual count 1
# The approximate count by cms: 1
# The error is: 0
# eglise
# The actual count 1
# The approximate count by cms: 2
# The error is: 1
# Elidus,
# The actual count 1
# The approximate count by cms: 1
# The error is: 0
# terë
# The actual count 1
# The approximate count by cms: 2
# The error is: 1
# argent.
# The actual count 1
# The approximate count by cms: 1
# The error is: 0
# Hummes
# The actual count 1
# The approximate count by cms: 1
# The error is: 0
# religïun
# The actual count 1
# The approximate count by cms: 1
# The error is: 0
# tenir
# The actual count 1
# The approximate count by cms: 3
# The error is: 2
# l'ordre
# The actual count 1
# The approximate count by cms: 3
# The error is: 2
# appareillé,
# The actual count 1
# The approximate count by cms: 1
# The error is: 0
# Nen
# The actual count 1
# The approximate count by cms: 6
# The error is: 5
# (a)targé:
# The actual count 1
# The approximate count by cms: 8
# The error is: 7
# rent
# The actual count 1
# The approximate count by cms: 1
# The error is: 0
# omnipotent.
# The actual count 1
# The approximate count by cms: 4
# The error is: 3
# Emsemble
# The actual count 1
# The approximate count by cms: 1
# The error is: 0
# premere
# The actual count 1
# The approximate count by cms: 3
# The error is: 2
# Mist
# The actual count 1
# The approximate count by cms: 1
# The error is: 0
# chere.
# The actual count 1
# The approximate count by cms: 1
# The error is: 0
# serur
# The actual count 1
# The approximate count by cms: 2
# The error is: 1
# porta
# The actual count 1
# The approximate count by cms: 1
# The error is: 0
# l'amonesta
# The actual count 1
# The approximate count by cms: 5
# The error is: 4
# ordre
# The actual count 1
# The approximate count by cms: 2
# The error is: 1
# enseigna.
# The actual count 1
# The approximate count by cms: 2
# The error is: 1
# priouent
# The actual count 1
# The approximate count by cms: 1
# The error is: 0
# merci;
# The actual count 1
# The approximate count by cms: 2
# The error is: 1
# eles
# The actual count 1
# The approximate count by cms: 2
# The error is: 1
# repreiot,
# The actual count 1
# The approximate count by cms: 1
# The error is: 0
# enveiot
# The actual count 1
# The approximate count by cms: 2
# The error is: 1
# saveir
# The actual count 1
# The approximate count by cms: 2
# The error is: 1
# cument
# The actual count 1
# The approximate count by cms: 3
# The error is: 2
# chescune
# The actual count 1
# The approximate count by cms: 2
# The error is: 1
# cunforteit.
# The actual count 1
# The approximate count by cms: 6
# The error is: 5
# pena
# The actual count 1
# The approximate count by cms: 3
# The error is: 2
# (par)
# The actual count 1
# The approximate count by cms: 1
# The error is: 0
# fin,
# The actual count 1
# The approximate count by cms: 1
# The error is: 0
# merci
# The actual count 1
# The approximate count by cms: 2
# The error is: 1
# devin.
# The actual count 1
# The approximate count by cms: 1
# The error is: 0
# ces
# The actual count 1
# The approximate count by cms: 2
# The error is: 1
# Bretun
# The actual count 1
# The approximate count by cms: 1
# The error is: 0
# Firent
# The actual count 1
# The approximate count by cms: 3
# The error is: 2
# remembrer,
# The actual count 1
# The approximate count by cms: 2
# The error is: 1
# oblïer.
# The actual count 1
# The approximate count by cms: 1
# The error is: 0
